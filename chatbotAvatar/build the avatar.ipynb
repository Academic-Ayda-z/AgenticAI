# %%
from google import genai
api_key='AIzaSyBExH0iv84m3JRbloT3-VYbIRqQx3p7TSQ'
client = genai.Client(api_key=api_key)

with open("persona.txt", "r", encoding="utf-8") as f:
    persona = f.read()

while True:
    question = input("You: ")

    prompt = f"""
You are an AI representation of this person:

{persona}

Answer as this person would.

Question: {question}
"""

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )

    print(response.text)
